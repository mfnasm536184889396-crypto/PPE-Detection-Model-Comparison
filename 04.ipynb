# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/PPE_Project/results
# Out:
# RT-DETR  YOLOv10  YOLOv10-2  YOLOv10-3	YOLOv11  YOLOv12

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.6/45.6 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 52.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 kB 6.5 MB/s eta 0:00:00
# ...

# %%
# !ls /content/drive/MyDrive/PPE_Project/results/RT-DETR/weights
# Out:
# best.pt  last.pt

# %%
from ultralytics import YOLO

model = YOLO("/content/drive/MyDrive/PPE_Project/results/RT-DETR/weights/last.pt")

model.train(resume=True)
# Out:
# Creating new Ultralytics Settings v0.0.7 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.4.123 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8-worldv2.pt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1467/3968542657.py in <cell line: 0>()
# ----> 1 model = YOLO("yolov8-worldv2.pt")
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/models/yolo/model.py in __init__(self, model, task, verbose)
#      71         path = Path(model if isinstance(model, (str, Path)) else "")
#      72         if "-world" in path.stem and path.suffix in {".pt", ".yaml", ".yml"}:  # if YOLOWorld PyTorch model
# ---> 73             new_instance = YOLOWorld(path, verbose=verbose)
#      74             self.__class__ = type(new_instance)
#      75             self.__dict__ = new_instance.__dict__
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/models/yolo/model.py in __init__(self, model, verbose)
#     172             verbose (bool): If True, prints additional information during initialization.
#     173         """
# ...

# %%
# !wget https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8s-worldv2.pt
# Out:
# --2026-08-20 08:18:04--  https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8s-worldv2.pt
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8s-worldv2.pt")

# %%
model.set_classes([
    "Hardhat",
    "Mask",
    "NO-Hardhat",
    "NO-Mask",
    "NO-Safety Vest",
    "Person",
    "Safety Cone",
    "Safety Vest",
    "machinery",
    "vehicle"
])
# Out:
# requirements: Ultralytics requirement ['git+https://github.com/ultralytics/CLIP.git'] not found, attempting AutoUpdate...
# Using Python 3.12.13 environment at: /usr
# Resolved 37 packages in 1.12s
# Prepared 2 packages in 2.41s
# Installed 2 packages in 1ms
#  + clip==1.0 (from git+https://github.com/ultralytics/CLIP.git@488e81a6711eea7346872b46ea928b367da8889d)
#  + ftfy==6.3.1
#
# requirements: AutoUpdate success ✅ 4.0s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
# 100%|███████████████████████████████████████| 338M/338M [00:04<00:00, 82.5MiB/s]

# %%
results = model.val(
    data="/content/drive/MyDrive/PPE_Project/PPE_data_colab.yaml",
    project="/content/drive/MyDrive/PPE_Project/results",
    name="YOLO-World"
)
# Out:
# Ultralytics 8.4.123 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLOv8s-worldv2 summary: 236 layers, 164,026,601 parameters, 151,277,313 gradients, 31.9 GFLOPs
# WARNING ⚠️ val: Slow image access detected (ping: 0.7±0.1 ms, read: 41.0±9.3 MB/s, size: 56.0 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# val: Scanning /content/drive/.shortcut-targets-by-id/18MuTpftoAIIQ_Mad7e5UCpH9O2-k9Cwm/PPE_Project/Construction-Site-Safety-28/valid/labels.cache... 114 images, 10 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 114/114 26.6Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.0it/s 4.0s
#                    all        114        697      0.572      0.267      0.361      0.235
#                Hardhat         42         79      0.966      0.358      0.717      0.509
# ...

# %%
# !ls /content/drive/MyDrive/PPE_Project/results
# Out:
# RT-DETR  YOLOv10  YOLOv10-2  YOLOv10-3	YOLOv11  YOLOv12  YOLO-World

# %%
# !find /content/drive/MyDrive/PPE_Project -name "best.pt"
